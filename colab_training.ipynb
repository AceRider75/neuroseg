# %% [markdown]
# #NeuroSeg: Google Colab GPU Trainer
#
# This notebook allows you to train the NeuroSeg U-Net model using Colab's free GPU resources.
#
# ### Step 1: Connect to GPU
# Go to **Runtime** -> **Change runtime type** and select **T4 GPU** (or any available GPU).

# %%
# Step 2: Mount Google Drive
from google.colab import drive
import os
drive.mount('/content/drive')

# Step 3: Navigate to your project folder
# CHANGE THIS to the actual path in your Google Drive
PROJECT_PATH = '/content/drive/MyDrive/neuroseg'
os.chdir(PROJECT_PATH)
print(f"Current Directory: {os.getcwd()}")
# Out:
# Mounted at /content/drive
# Current Directory: /content/drive/MyDrive/neuroseg

# %% [markdown]
# ### Step 4: Install Dependencies
# Colab comes with torch pre-installed, but we need a few specific medical imaging libraries.

# %%
# !pip install albumentations opencv-python-headless tqdm
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (2.0.8)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (4.13.0.90)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations) (1.16.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from albumentations) (6.0.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations) (0.0.24)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (6.5.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.4.2)

# %% [markdown]
# ### Step 5: Start Training
# This will run the training script we implemented. It will automatically detect the GPU.

# %%
# !python3 train.py
# Out:
# Using device: cuda
# Dataset Split Summary:
# Total Patients: 110
# Train: 2858 slices (78 patients)
# Val:   540 slices (16 patients)
# Test:  531 slices (16 patients)
#
# Epoch 1/50
# Training: 100% 715/715 [18:03<00:00,  1.52s/it, loss=0.935, dice=0.191]
# Validation: 100% 135/135 [03:24<00:00,  1.51s/it]
# Summary - Train Loss: 1.1998, Train Dice: 0.0655
# Summary - Val Loss: 1.0999, Val Dice: 0.0737
# New best model saved with Val Dice: 0.0737
#
# Epoch 2/50
# Training: 100% 715/715 [03:03<00:00,  3.90it/s, loss=1.05, dice=0.000275]
# Validation: 100% 135/135 [00:12<00:00, 11.21it/s]
# Summary - Train Loss: 0.9028, Train Dice: 0.1791
# Summary - Val Loss: 0.8712, Val Dice: 0.1978
# New best model saved with Val Dice: 0.1978
#
# Epoch 3/50
# Training: 100% 715/715 [03:04<00:00,  3.88it/s, loss=1.01, dice=0.00446]
# Validation: 100% 135/135 [00:12<00:00, 11.11it/s]
# Summary - Train Loss: 0.7006, Train Dice: 0.3408
# Summary - Val Loss: 0.7129, Val Dice: 0.3104
# New best model saved with Val Dice: 0.3104
#
# Epoch 4/50
# Training: 100% 715/715 [03:03<00:00,  3.90it/s, loss=0.278, dice=0.738]
# Validation: 100% 135/135 [00:12<00:00, 11.23it/s]
# Summary - Train Loss: 0.5784, Train Dice: 0.4558
# Summary - Val Loss: 0.6529, Val Dice: 0.3829
# New best model saved with Val Dice: 0.3829
#
# Epoch 5/50
# Training: 100% 715/715 [03:03<00:00,  3.89it/s, loss=0.255, dice=0.787]
# Validation: 100% 135/135 [00:12<00:00, 11.14it/s]
# Summary - Train Loss: 0.5248, Train Dice: 0.5071
# Summary - Val Loss: 0.5553, Val Dice: 0.4646
# New best model saved with Val Dice: 0.4646
#
# Epoch 6/50
# Training: 100% 715/715 [03:04<00:00,  3.88it/s, loss=0.222, dice=0.788]
# Validation: 100% 135/135 [00:12<00:00, 11.17it/s]
# Summary - Train Loss: 0.4942, Train Dice: 0.5363
# Summary - Val Loss: 0.5785, Val Dice: 0.4551
#
# Epoch 7/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=0.624, dice=0.435]
# Validation: 100% 135/135 [00:12<00:00, 11.23it/s]
# Summary - Train Loss: 0.4981, Train Dice: 0.5330
# Summary - Val Loss: 0.5335, Val Dice: 0.4897
# New best model saved with Val Dice: 0.4897
#
# Epoch 8/50
# Training: 100% 715/715 [03:05<00:00,  3.86it/s, loss=0.0906, dice=0.922]
# Validation: 100% 135/135 [00:12<00:00, 11.07it/s]
# Summary - Train Loss: 0.4884, Train Dice: 0.5411
# Summary - Val Loss: 0.5237, Val Dice: 0.4968
# New best model saved with Val Dice: 0.4968
#
# Epoch 9/50
# Training: 100% 715/715 [03:03<00:00,  3.90it/s, loss=1.03, dice=0.000833]
# Validation: 100% 135/135 [00:12<00:00, 11.21it/s]
# Summary - Train Loss: 0.4631, Train Dice: 0.5651
# Summary - Val Loss: 0.4977, Val Dice: 0.5223
# New best model saved with Val Dice: 0.5223
#
# Epoch 10/50
# Training: 100% 715/715 [03:04<00:00,  3.87it/s, loss=0.37, dice=0.653]
# Validation: 100% 135/135 [00:12<00:00, 11.15it/s]
# Summary - Train Loss: 0.4698, Train Dice: 0.5598
# Summary - Val Loss: 0.5182, Val Dice: 0.5158
#
# Epoch 11/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=1.04, dice=0.000678]
# Validation: 100% 135/135 [00:12<00:00, 11.08it/s]
# Summary - Train Loss: 0.4585, Train Dice: 0.5694
# Summary - Val Loss: 0.5179, Val Dice: 0.5108
#
# Epoch 12/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=0.619, dice=0.397]
# Validation: 100% 135/135 [00:11<00:00, 11.26it/s]
# Summary - Train Loss: 0.4567, Train Dice: 0.5723
# Summary - Val Loss: 0.5079, Val Dice: 0.5161
#
# Epoch 13/50
# Training: 100% 715/715 [03:02<00:00,  3.93it/s, loss=1.02, dice=0.00301]
# Validation: 100% 135/135 [00:12<00:00, 11.09it/s]
# Summary - Train Loss: 0.4449, Train Dice: 0.5856
# Summary - Val Loss: 0.4653, Val Dice: 0.5591
# New best model saved with Val Dice: 0.5591
#
# Epoch 14/50
# Training: 100% 715/715 [03:05<00:00,  3.86it/s, loss=0.131, dice=0.886]
# Validation: 100% 135/135 [00:12<00:00, 11.09it/s]
# Summary - Train Loss: 0.4379, Train Dice: 0.5958
# Summary - Val Loss: 0.4814, Val Dice: 0.5528
#
# Epoch 15/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=0.315, dice=0.773]
# Validation: 100% 135/135 [00:12<00:00, 11.15it/s]
# Summary - Train Loss: 0.4209, Train Dice: 0.6177
# Summary - Val Loss: 0.3560, Val Dice: 0.6754
# New best model saved with Val Dice: 0.6754
#
# Epoch 16/50
# Training: 100% 715/715 [03:03<00:00,  3.89it/s, loss=1.26, dice=0.000395]
# Validation: 100% 135/135 [00:12<00:00, 11.02it/s]
# Summary - Train Loss: 0.4877, Train Dice: 0.5627
# Summary - Val Loss: 0.7304, Val Dice: 0.3503
#
# Epoch 17/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=1.04, dice=0.000602]
# Validation: 100% 135/135 [00:12<00:00, 11.16it/s]
# Summary - Train Loss: 0.4782, Train Dice: 0.5764
# Summary - Val Loss: 0.3716, Val Dice: 0.6594
#
# Epoch 18/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=1, dice=0.00454]
# Validation: 100% 135/135 [00:12<00:00, 11.03it/s]
# Summary - Train Loss: 0.4437, Train Dice: 0.6071
# Summary - Val Loss: 0.4023, Val Dice: 0.6337
#
# Epoch 19/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=0.144, dice=0.873]
# Validation: 100% 135/135 [00:12<00:00, 11.16it/s]
# Summary - Train Loss: 0.4344, Train Dice: 0.6176
# Summary - Val Loss: 0.4120, Val Dice: 0.6153
#
# Epoch 20/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=0.208, dice=0.805]
# Validation: 100% 135/135 [00:12<00:00, 11.12it/s]
# Summary - Train Loss: 0.3854, Train Dice: 0.6573
# Summary - Val Loss: 0.4532, Val Dice: 0.5920
#
# Epoch 21/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=1.02, dice=0.00178]
# Validation: 100% 135/135 [00:12<00:00, 11.14it/s]
# Summary - Train Loss: 0.3921, Train Dice: 0.6455
# Summary - Val Loss: 0.4059, Val Dice: 0.6243
#
# Epoch 22/50
# Training: 100% 715/715 [03:02<00:00,  3.92it/s, loss=0.00868, dice=0.991]
# Validation: 100% 135/135 [00:12<00:00, 11.12it/s]
# Summary - Train Loss: 0.3250, Train Dice: 0.7060
# Summary - Val Loss: 0.3555, Val Dice: 0.6707
#
# Epoch 23/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=0.00733, dice=0.993]
# Validation: 100% 135/135 [00:12<00:00, 11.14it/s]
# Summary - Train Loss: 0.3198, Train Dice: 0.7078
# Summary - Val Loss: 0.3639, Val Dice: 0.6623
#
# Epoch 24/50
# Training: 100% 715/715 [03:02<00:00,  3.92it/s, loss=0.0119, dice=0.988]
# Validation: 100% 135/135 [00:12<00:00, 11.14it/s]
# Summary - Train Loss: 0.3252, Train Dice: 0.7022
# Summary - Val Loss: 0.3709, Val Dice: 0.6533
#
# Epoch 25/50
# Training: 100% 715/715 [03:02<00:00,  3.93it/s, loss=0.00666, dice=0.993]
# Validation: 100% 135/135 [00:12<00:00, 11.02it/s]
# Summary - Train Loss: 0.3035, Train Dice: 0.7242
# Summary - Val Loss: 0.3386, Val Dice: 0.6866
# New best model saved with Val Dice: 0.6866
#
# Epoch 26/50
# Training: 100% 715/715 [03:04<00:00,  3.89it/s, loss=0.171, dice=0.897]
# Validation: 100% 135/135 [00:12<00:00, 11.17it/s]
# Summary - Train Loss: 0.3137, Train Dice: 0.7148
# Summary - Val Loss: 0.3798, Val Dice: 0.6444
#
# Epoch 27/50
# Training: 100% 715/715 [03:02<00:00,  3.92it/s, loss=0.148, dice=0.859]
# Validation: 100% 135/135 [00:12<00:00, 11.00it/s]
# Summary - Train Loss: 0.2918, Train Dice: 0.7344
# Summary - Val Loss: 0.3986, Val Dice: 0.6236
#
# Epoch 28/50
# Training: 100% 715/715 [03:01<00:00,  3.94it/s, loss=0.01, dice=0.99]
# Validation: 100% 135/135 [00:12<00:00, 11.15it/s]
# Summary - Train Loss: 0.2890, Train Dice: 0.7379
# Summary - Val Loss: 0.4035, Val Dice: 0.6301
#
# Epoch 29/50
# Training: 100% 715/715 [03:02<00:00,  3.93it/s, loss=1.07, dice=0.00193]
# Validation: 100% 135/135 [00:12<00:00, 11.24it/s]
# Summary - Train Loss: 0.3049, Train Dice: 0.7229
# Summary - Val Loss: 0.3067, Val Dice: 0.7208
# New best model saved with Val Dice: 0.7208
#
# Epoch 30/50
# Training: 100% 715/715 [03:04<00:00,  3.88it/s, loss=0.491, dice=0.698]
# Validation: 100% 135/135 [00:12<00:00, 10.98it/s]
# Summary - Train Loss: 0.2909, Train Dice: 0.7369
# Summary - Val Loss: 0.3526, Val Dice: 0.6720
#
# Epoch 31/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=0.22, dice=0.803]
# Validation: 100% 135/135 [00:12<00:00, 11.17it/s]
# Summary - Train Loss: 0.2887, Train Dice: 0.7371
# Summary - Val Loss: 0.3092, Val Dice: 0.7155
#
# Epoch 32/50
# Training: 100% 715/715 [03:02<00:00,  3.92it/s, loss=1.04, dice=0.217]
# Validation: 100% 135/135 [00:12<00:00, 11.11it/s]
# Summary - Train Loss: 0.2798, Train Dice: 0.7458
# Summary - Val Loss: 0.3149, Val Dice: 0.7101
#
# Epoch 33/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=0.00501, dice=0.995]
# Validation: 100% 135/135 [00:12<00:00, 11.16it/s]
# Summary - Train Loss: 0.2967, Train Dice: 0.7289
# Summary - Val Loss: 0.2990, Val Dice: 0.7261
# New best model saved with Val Dice: 0.7261
#
# Epoch 34/50
# Training: 100% 715/715 [03:05<00:00,  3.86it/s, loss=0.00886, dice=0.991]
# Validation: 100% 135/135 [00:12<00:00, 11.17it/s]
# Summary - Train Loss: 0.2884, Train Dice: 0.7377
# Summary - Val Loss: 0.3290, Val Dice: 0.6982
#
# Epoch 35/50
# Training: 100% 715/715 [03:02<00:00,  3.93it/s, loss=0.00613, dice=0.994]
# Validation: 100% 135/135 [00:12<00:00, 10.99it/s]
# Summary - Train Loss: 0.2870, Train Dice: 0.7391
# Summary - Val Loss: 0.3260, Val Dice: 0.6976
#
# Epoch 36/50
# Training: 100% 715/715 [03:02<00:00,  3.92it/s, loss=0.0908, dice=0.923]
# Validation: 100% 135/135 [00:12<00:00, 11.20it/s]
# Summary - Train Loss: 0.2869, Train Dice: 0.7384
# Summary - Val Loss: 0.3388, Val Dice: 0.6850
#
# Epoch 37/50
# Training: 100% 715/715 [03:02<00:00,  3.93it/s, loss=0.00376, dice=0.996]
# Validation: 100% 135/135 [00:12<00:00, 11.06it/s]
# Summary - Train Loss: 0.2771, Train Dice: 0.7481
# Summary - Val Loss: 0.3292, Val Dice: 0.6960
#
# Epoch 38/50
# Training: 100% 715/715 [03:01<00:00,  3.94it/s, loss=0.0801, dice=0.925]
# Validation: 100% 135/135 [00:12<00:00, 11.03it/s]
# Summary - Train Loss: 0.2914, Train Dice: 0.7337
# Summary - Val Loss: 0.2834, Val Dice: 0.7431
# New best model saved with Val Dice: 0.7431
#
# Epoch 39/50
# Training: 100% 715/715 [03:04<00:00,  3.88it/s, loss=1, dice=0.00743]
# Validation: 100% 135/135 [00:12<00:00, 11.23it/s]
# Summary - Train Loss: 0.2707, Train Dice: 0.7539
# Summary - Val Loss: 0.2928, Val Dice: 0.7323
#
# Epoch 40/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=0.0106, dice=0.989]
# Validation: 100% 135/135 [00:12<00:00, 11.06it/s]
# Summary - Train Loss: 0.2997, Train Dice: 0.7254
# Summary - Val Loss: 0.2926, Val Dice: 0.7300
#
# Epoch 41/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=0.918, dice=0.0823]
# Validation: 100% 135/135 [00:12<00:00, 11.16it/s]
# Summary - Train Loss: 0.2819, Train Dice: 0.7423
# Summary - Val Loss: 0.2996, Val Dice: 0.7237
#
# Epoch 42/50
# Training: 100% 715/715 [03:02<00:00,  3.92it/s, loss=0.213, dice=0.81]
# Validation: 100% 135/135 [00:12<00:00, 11.09it/s]
# Summary - Train Loss: 0.2687, Train Dice: 0.7553
# Summary - Val Loss: 0.3784, Val Dice: 0.6449
#
# Epoch 43/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=0.00283, dice=0.997]
# Validation: 100% 135/135 [00:12<00:00, 11.22it/s]
# Summary - Train Loss: 0.2904, Train Dice: 0.7353
# Summary - Val Loss: 0.3028, Val Dice: 0.7251
#
# Epoch 44/50
# Training: 100% 715/715 [03:02<00:00,  3.92it/s, loss=0.148, dice=0.861]
# Validation: 100% 135/135 [00:12<00:00, 11.11it/s]
# Summary - Train Loss: 0.2848, Train Dice: 0.7407
# Summary - Val Loss: 0.3255, Val Dice: 0.6972
#
# Epoch 45/50
# Training: 100% 715/715 [03:02<00:00,  3.93it/s, loss=0.908, dice=0.171]
# Validation: 100% 135/135 [00:12<00:00, 11.11it/s]
# Summary - Train Loss: 0.2741, Train Dice: 0.7504
# Summary - Val Loss: 0.3324, Val Dice: 0.6921
#
# Epoch 46/50
# Training: 100% 715/715 [03:02<00:00,  3.92it/s, loss=1.07, dice=0.0248]
# Validation: 100% 135/135 [00:12<00:00, 11.18it/s]
# Summary - Train Loss: 0.2780, Train Dice: 0.7459
# Summary - Val Loss: 0.3434, Val Dice: 0.6805
#
# Epoch 47/50
# Training: 100% 715/715 [03:02<00:00,  3.93it/s, loss=0.233, dice=0.78]
# Validation: 100% 135/135 [00:12<00:00, 11.06it/s]
# Summary - Train Loss: 0.2791, Train Dice: 0.7446
# Summary - Val Loss: 0.3275, Val Dice: 0.6963
#
# Epoch 48/50
# Training: 100% 715/715 [03:02<00:00,  3.92it/s, loss=0.00477, dice=0.995]
# Validation: 100% 135/135 [00:12<00:00, 11.14it/s]
# Summary - Train Loss: 0.2664, Train Dice: 0.7567
# Summary - Val Loss: 0.3139, Val Dice: 0.7115
#
# Epoch 49/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=0.0235, dice=0.977]
# Validation: 100% 135/135 [00:12<00:00, 10.93it/s]
# Summary - Train Loss: 0.2734, Train Dice: 0.7502
# Summary - Val Loss: 0.3358, Val Dice: 0.6889
#
# Epoch 50/50
# Training: 100% 715/715 [03:01<00:00,  3.93it/s, loss=0.00575, dice=0.994]
# Validation: 100% 135/135 [00:12<00:00, 11.16it/s]
# Summary - Train Loss: 0.2679, Train Dice: 0.7547
# Summary - Val Loss: 0.3361, Val Dice: 0.6855

# %% [markdown]
# ### Step 6: Verify Persistence
# After training, `best_model.pth` will be saved directly back to your Google Drive folder, ready for use in the Streamlit app later.
